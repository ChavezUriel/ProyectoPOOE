# %%
import objast as oa

# %%
# Creación de objetos astronómicos
lista_objetos = oa.generarObjetos(1000)

# Obtener las posiciones en un arreglo
posiciones = oa.getpos(lista_objetos)

# De esta función podemos graficar directamente
oa.mollweide_plot(posiciones)

# %%
# Atributos de los objetos
atributos = list(lista_objetos[0].__dict__.keys())

print("Atributos de cada objeto: ")

for i in range(len(atributos)):
    print(atributos[i])
# Out:
# Atributos de cada objeto:
# espectro
# tipo_objeto
# tipo_espectro
# z
# RA_DEC

# %%
print("Objeto i = 0")
print("RA,DEC: ",lista_objetos[0].RA_DEC)
print("z: ",lista_objetos[0].z)
print("Tipo de espectro: ",lista_objetos[0].tipo_espectro)
# Out:
# Objeto i = 0
# RA,DEC:  [ 1.60056371 -0.35848076]
# z:  2.8380134497621605
# Tipo de espectro:  QSO+

# %%
# Graficar el espectro
# si la etiqueta mostrando el valor de z es molesta, 
# se puede quitar comentando una línea en el módulo objast
oa.construir_espectro(lista_objetos[0])

# %%
# Generar lista de objetos con cantidades personalizadas de objetos
lista_objetos = oa.generarObjetos(custom = True, n_galmas=3, n_galmenos=3, n_qsomas=3, n_qsomenos=3)

# %%
for i in [0,3,6,9]:
    print("\nObjeto i = ", i)
    print("RA,DEC: ",lista_objetos[i].RA_DEC)
    print("z: ",lista_objetos[i].z)
    print("Tipo de espectro: ",lista_objetos[i].tipo_espectro)
# Out:
# Objeto i =  0
# RA,DEC:  [ 2.64291288 -0.03633389]
# z:  2.4222065275896023
# Tipo de espectro:  QSO+
#
# Objeto i =  3
# RA,DEC:  [ 1.43832802 -0.38731493]
# z:  1.7054545548619355
# Tipo de espectro:  QSO-
#
# Objeto i =  6
# RA,DEC:  [ 1.62309493 -1.11168864]
# z:  2.3253254711787776
# Tipo de espectro:  GAL
#
# Objeto i =  9
# RA,DEC:  [-0.22507162 -0.08974778]
# z:  1.270128037111951
# Tipo de espectro:  GAL

# %%
[objeto.tipo_espectro for objeto in lista_objetos]
# Out:
# ['QSO+',
#  'QSO+',
#  'QSO+',
#  'QSO-',
#  'QSO-',
#  'QSO-',
#  'GAL',
#  'GAL',
#  'GAL',
#  'GAL',
#  'GAL',
#  'GAL']

# %%
oa.plotrecons(lista_objetos[0])

# %%
#Crea una tabla de valores con el espectro y medidas del espectro
oa.datos_espectro(lista_objetos[0])
# Out:
#       wavelengths   espectro
# 0     1042.302513  32.968719
# 1     1042.542539  27.295497
# 2     1042.782621  33.255263
# 3     1043.022758  32.433744
# 4     1043.262951  27.586676
# ...           ...        ...
# 4622  3021.299541  22.169213
# 4623  3021.995301  24.006320
# 4624  3022.691221  22.486072
# 4625  3023.387301  18.679270
# 4626  3024.083542  32.906997
#
# [4627 rows x 2 columns]

# %%
#clase qsomas y su metodo generar espectro
obj1=oa.qsomas()
obj1.generarEspectro()
# Out:
# array([ 1.54031489e+02,  2.49927168e+01,  2.26159119e+00,  1.89668388e+01,
#         2.27945692e+01,  1.42597816e+01, -3.98599197e+01,  2.32032715e+01,
#         3.46746410e+01,  7.79420096e+00,  2.31622289e+01, -3.57609096e+00,
#        -7.30269203e+00,  6.57905438e+00,  9.25656535e+00,  5.96346672e+00,
#        -5.08897233e+00, -3.71892564e+00,  3.04287304e+01, -8.97797043e+00,
#        -4.74830411e+00, -2.19071382e+00,  3.04554733e+01,  2.89638159e+00,
#        -4.22388636e+00, -1.75920767e+00,  2.14528366e+00, -3.51791645e+01,
#        -1.11662351e+00,  1.36605117e+01,  1.57795415e+01, -4.45825106e-02,
#         7.48386249e+00,  1.00999853e+01, -2.04504856e+00,  1.43962687e+01,
#        -9.10389502e+00,  8.20611073e+00,  1.00658618e+01,  5.04924675e+00,
#        -4.98745956e-01, -1.37431939e+01,  2.61054731e+00,  4.14326302e+00,
#         8.49428217e+00,  2.04450782e+00,  7.56520707e+00, -3.63154759e+00,
#        -3.78234496e-01, -5.32858382e+00])

# %%
#Clase qsomenos y su método generar espectro
obj2=oa.qsomenos()
obj2.generarEspectro()
# Out:
# array([-111.59535334,  -52.85651182,    4.66698795,   -5.43946491,
#         132.72724182,    2.74468023,   18.10498485,  -18.2107696 ,
#         -11.01734133,   -2.76759167,   -3.84136135,    4.3240937 ,
#           2.93345504,   -1.68681417,  -10.98489767,  -11.51211688,
#          -0.6916641 ,  -18.46222331,    6.01488123,  -13.85600234,
#         -26.39395575,    1.36649753,    4.91871048,   -0.23859894,
#           0.3339818 ,    1.56386798,    2.94971673,   -0.77275669,
#         -17.12429467,    1.24058124,   -5.07785955,  -13.03057882,
#           6.55877782,   10.4698729 ,    6.60901586,    8.23476767,
#          -1.25508645,   -7.21534206,  -19.02506583,    3.24440476,
#          -1.88315471,   -0.17978268,    9.78491582,    7.11965842,
#          -5.14376455,    1.86198252,    7.60857456,   -7.7464466 ,
#           3.3709626 ,   10.33056065])

# %%
#Clase galmas y su método generar espectro
obj3=oa.galmas()
obj3.generarEspectro()
# Out:
# array([ 1.25170150e+01, -1.34538931e+02, -1.93485666e+01, -2.08315038e+01,
#        -4.88880739e+00, -3.03378642e+01,  1.20104287e+01,  8.91492903e+01,
#         7.91994035e+00,  1.01551653e+01, -2.68959082e+00, -1.56091735e+01,
#        -1.44281717e+01,  8.82993719e-01,  7.63463063e+01, -4.40912430e+00,
#        -5.26667667e+00, -4.82839641e+00, -3.37677823e-01,  8.33816464e+00,
#         2.41349436e+00,  2.65355561e-01,  1.32343573e+01,  8.29855830e+00,
#        -2.48845766e+00, -3.17747568e-01, -8.95721481e+00, -6.78590552e-02,
#        -9.14777052e+00,  1.30431254e+01, -1.48441203e-01, -3.80253400e+00,
#         4.27064284e+00,  4.77170883e-01,  1.86385716e+00,  2.29788902e+00,
#         3.68023400e+00, -9.10129038e+00, -4.32067769e+00, -1.67970962e+01,
#        -1.48115085e+00, -1.26439038e-02, -3.48776050e+00, -4.44065036e+00,
#         6.84150621e-01,  6.92304802e+00, -1.53935570e+00, -3.76332063e+00,
#        -4.39339853e+00, -3.66340282e+00])

# %%
#Clase galmenos y su método generar espectro
obj4=oa.galmenos()
obj4.generarEspectro()
# Out:
# array([ 4.77504540e+02,  5.14592076e+01,  1.76075752e+01, -1.70456038e+01,
#         7.00220394e+00, -1.90406993e+01,  3.46791867e+00, -2.68795479e+01,
#        -1.29067268e+02, -1.88062451e+01,  9.51417992e-01,  3.07360940e+00,
#        -1.30329098e+01, -3.24965266e+00, -3.97016175e+00, -3.70892160e+00,
#         5.34556676e+00,  4.59579928e+00,  1.02633580e+00,  9.09099548e+00,
#        -1.91827055e+00,  3.09986548e+00,  1.29473084e+00, -7.04287501e+00,
#         3.28503558e+00,  1.68830238e+01,  2.60502396e+00,  9.85886448e+00,
#        -9.34603073e+00,  1.45047827e+00,  2.26882080e-01, -2.45232766e+00,
#        -3.75508507e+00, -4.37598096e+00,  1.61444711e+00, -6.66497376e+00,
#        -6.01517819e+00,  4.48982151e+00,  3.44110503e+00, -6.68534317e-01,
#         4.65589898e+00,  9.13429264e-01, -5.66016470e+00,  2.02916584e+00,
#         6.96392014e+00,  3.60114113e+00, -8.05339864e+00, -1.78698164e-01,
#         2.62282417e+00, -7.27821674e-01])

# %%
#Clase oamas y su método generarZ
obj5=oa.oamas()
obj5.generarZ()
# Out:
# 2.1490801261716763

# %%
#Clase oamenos y su método generarZ
obj6=oa.oamenos()
obj6.generarZ()
# Out:
# 1.4586186101046112

# %%
#Clase qsomenos y su método rand_sphere
obj7=oa.objast()
obj7.rand_sphere()
# Out:
# array([ 2.08133331, -0.53670579])

# %%
# Carga la distribución de los objetos en z (corrimiento al rojo), se usa también KDE
oa.loadKde_z()
# Out:
# KernelDensity(bandwidth=0.13809375)

# %%
# Genera z's muestreando el KDE obtenido de la función anterior
oa.generarZ()
# Out:
# 2.517522461504171
